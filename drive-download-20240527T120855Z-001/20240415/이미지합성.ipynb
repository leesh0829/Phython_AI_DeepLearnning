# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
HOME = '/content/drive/MyDrive/20240415'

import os
# %cd {HOME}
# Out:
# /content/drive/MyDrive/20240415

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('phone.jpg')
overlay_img = cv2.imread('tree.png', cv2.IMREAD_UNCHANGED)
print(overlay_img.shape)
# Out:
# (1200, 1200, 4)

# %%
overlay_img = cv2.resize(overlay_img, dsize=(350, 350))
overlay_alpha = overlay_img[:, :, 3:] / 255.0
background_alpha = 1 - overlay_alpha

# %%
x1 = 430
y1 = 90
x2 = x1 + 350
y2 = y1 + 350

# %%
img[y1:y2, x1:x2] = overlay_alpha * overlay_img[:, :, :3] + background_alpha * img[y1:y2, x1:x2]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x600>

# %%
img = cv2.imread('bingha.jpg')
overlay_img = cv2.imread('dora.png', cv2.IMREAD_UNCHANGED)
print(img.shape)
print(overlay_img.shape)
# Out:
# (183, 275, 3)
# (373, 670, 4)

# %%
overlay_img = cv2.resize(overlay_img, dsize=(50, 50))
overlay_alpha = overlay_img[:, :, 3:] / 255.0
background_alpha = 1 - overlay_alpha

# %%
x1 = 200
y1 = 120
x2 = x1 + 50
y2 = y1 + 50

# %%
img[y1:y2, x1:x2] = overlay_alpha * overlay_img[:, :, :3] + background_alpha * img[y1:y2, x1:x2]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
